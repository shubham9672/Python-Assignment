# %% [markdown]
# Q-1 Create a class called Country which has a single class attribute called AVG_POPULATION.
# Set it to some default value. The constructor takes the parameters country_name and country_code.
# The constructor must check that country_name and country_code are strings. If not it must throw a ValueError.
# The constructor must check if the country code is exactly 3 letters long. If not it must throw a ValueError.
#
#
# * Write a method called country_short_form() which takes the country_name as a parameter and returns the first 2 letters of the country name in uppercase. Suitable validations must be done for the method.
#
# * Write a class method called is_densly_populated(), which takes a single parameter `population` and returns true if the population is greater than AVG_POPULATION otherwise false. Suitable validations must be done for the method.
#
# * Write a static method called world_avg_population(), which takes an array of numbers of the different country populations and returns the average of the numbers. Suitable validations must be done for the method.
#
#
# * Write a method called formatted_country_name which returns a string containing the `country_name ( country_code)` [ ex - India ( IND) ]. Make this method into a property using decorators, and write a getter, setter, and a deleter for manipulating the values of country_name and country_code. Suitable validations must be done for the method.

# %%
class Country:
    def __init__(self,country_name,country_code):
        self._avg_population=800000
        self.country_name=country_name
        self.country_code=country_code
        try:
            if(not isinstance(country_name,str) and not isinstance(country_code,str) and len(country_code)!=3):
                raise ValueError("ValueError: Country Code & Name must be String")
        except ValueError as error:
            print(error)
    def country_short_form(self):
        return (self.country_name[:2].upper())
    def is_densly_populated(self,population):
        if self._avg_population < population:
            return True
        else:
            return False
    @staticmethod
    def world_avg_population(array):
        return 'AVG Population = '+str(sum(array)/len(array))
    @property
    def formatted_country_name(self):
        return f'{self.country_name} ( {self.country_code})'

    @formatted_country_name.setter
    def formatted_country_name(self, cou_name,cou_code ):
        self.country_name = cou_name
        self.country_code = cou_code
 
    @formatted_country_name.deleter
    def formatted_country_name(self):
        self.country_name = ''
        self.country_code = '' 

# Creating Object of Country Class
obj = Country("India", "IND")

# Call country_short_form method & printing its result
print(obj.country_short_form())

# Call is_densly_populated method & printing its result
print(obj.is_densly_populated(1000505))

# call world_avg_population method & printing its result
print(obj.world_avg_population([8000,10000,96000,745000]))

# call setter and then getter
print(obj.formatted_country_name)
obj.country_name = "China"
obj.country_code = "CHN"
obj.formatted_country_name
#after change
print(obj.formatted_country_name)
# Call deleter
del obj.formatted_country_name
obj.formatted_country_name
# Out:
# IN
# True
# AVG Population = 214750.0
# India ( IND)
# China ( CHN)
# ' ( )'

# %% [markdown]
# Q-2 Create a base class Shapes. It must have 2 suitable instance variables and 2 suitable methods.
#
# * Create 2 child class of Shapes. For example Triangle and Quadrilateral. They must inherit the Shapes class and override 1 variable and 1 method. They must have 1 additional attribute and
# method.
#
# * Create 1 child class each of the above Triangle & Quadrilateral.
# They must override 1 method and have 2 additional attributes and 1 additional method.
#
# * Your program must instantiate the lowest child classes and print all attributes and methods of the class and all inherited attributes and methods as well. Suitable error handling must be done for all methods.

# %%
class Shapes:
    def __init__(self, side1, side2):
        self.side1 = side1
        self.side2 = side2
    
    def shape_side_sum(self):
        return f"sum of shape sides = {self.side1+self.side2}"
        
    def shape_area(self):
        return f"Area of shape = {self.side1*self.side2}"
class Triangle(Shapes):
    def __init__(self,side1,side2,side3):
        self.side3 = side3
        Shapes.__init__(self,side1,side2)
    def shape_side_sum(self):
        return f"sum of shape sides = {self.side1+self.side2+self.side3}"
        
    def validTriangle(self):
        if (self.side1 + self.side2 <= self.side3) or (self.side1 + self.side3 <= self.side2) or (self.side2 + self.side3 <= self.side1) :
            return 'Invalid Triangle'
        else:
            return 'Valid Triangle' 
class Quadrilateral(Shapes):
    def __init__(self, side1, side2,side3,side4):
        self.side3 = side3
        self.side4 = side4
        Shapes.__init__(self,side1,side2)
    
    def shape_side_sum(self):
        return f"sum of shape sides = {self.side1+self.side2+self.side3+self.side4}"
    
    def quadrilateral_method(self):
        return f"Quadrilateral Sides are: {self.side1}, {self.side2}, {self.side3}, {self.side4} "


class ChildTriangle(Triangle):
    def __init__(self, side1, side2, side3, height):
        self.height = height
        Triangle.__init__(self,side1,side2,side3)
        
    def validTriangle(self):
        a=self.side1 + self.side2
        b=self.side1 + self.side3
        c=self.side2 + self.side3
        if a<=self.side3 or b<=self.side2 or c<=self.side1:
            return False
        return True
    
    def child_triangle(self):
         return f"ChildTriangle Method Heigth of Triangle = {self.height}"
        



class ChildQuadrilateral(Quadrilateral):
    def __init__(self, side1, side2, side3,side4, var):
        self.var = var
        Quadrilateral.__init__(self,side1,side2,side3,side4)
        
    def quadrilateral_method(self):
        return f"Quadrilateral Sides & extra variable are: {self.side1}, {self.side2}, {self.side3}, {self.side4}, {self.var} "
    
    def child_quadrilateral(self):
        return f"Child Quadrilateral extra variable is = {self.var}"

def main():
    shape_side1 = 3
    shape_side2 = 4
    triangle_side3 = 5
    child_triangle_height = 5
    quadrilateral_side3 = 4
    quadrilateral_side4 = 6
    child_quadrilateral_exvar = 100
    
    print('\n\n---------------Shape---------------\n\n')
    # Create object of shape class
    shapes = Shapes(shape_side1, shape_side2)
    # Shapes's Method Call 
    print(shapes.shape_side_sum())
    print(shapes.shape_area())
    

    # Create object of Triangle class
    print('\n\n---------------Triangle---------------\n\n')
    triangle = Triangle(shape_side1, shape_side2,triangle_side3)
    # Triangle's Method Call (Child of Shapes Class) 
    print(triangle.shape_side_sum())
    print(triangle.validTriangle())
    
    
    print('\n\n---------------Quadrilateral---------------\n\n')
    # Create object of Quadrilateral Class
    quadrilateral = Quadrilateral(shape_side1, shape_side2,quadrilateral_side3,quadrilateral_side4)
    print(quadrilateral.shape_side_sum())
    print(quadrilateral.quadrilateral_method())
    
    print('\n\n---------------ChildTriangle---------------\n\n')
    # Create object of ChildTriangle class
    child_triangle = ChildTriangle(shape_side1, shape_side2,triangle_side3,child_triangle_height)
    
    # ChildTriangle's Method Call (Child of Triangle Class)
    print(child_triangle.validTriangle())
    print(child_triangle.child_triangle())
    
    print('\n\n---------------ChildQuadrilateral---------------\n\n')
    # Create object of ChildQuadrilateral Class
    child_quadrilateral = ChildQuadrilateral(shape_side1, shape_side2, quadrilateral_side3,quadrilateral_side4,child_quadrilateral_exvar)

    # ChildTriangle's Method Call (Child of Triangle Class)
    print(child_quadrilateral.quadrilateral_method())
    print(child_quadrilateral.child_quadrilateral())

    
if __name__=="__main__":
    main()
# Out:
# ---------------Shape---------------
#
#
# sum of shape sides = 7
# Area of shape = 12
#
#
# ---------------Triangle---------------
#
#
# sum of shape sides = 12
# Valid Triangle
#
#
# ---------------Quadrilateral---------------
#
#
# sum of shape sides = 17
# Quadrilateral Sides are: 3, 4, 4, 6
#
#
# ---------------ChildTriangle---------------
#
#
# True
# ChildTriangle Method Heigth of Triangle = 5
#
#
# ---------------ChildQuadrilateral---------------
#
#
# Quadrilateral Sides & extra variable are: 3, 4, 4, 6, 100
# Child Quadrilateral extra variable is = 100
